# %%
# %run EDA-Random-model-Univariate-2.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_6660\2285066288.py:3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from nltk.corpus import stopwords
#       4 import re
#       5 import time
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\__init__.py:133
#     125     subprocess.Popen = _fake_Popen
#     127 ###########################################################
#     128 # TOP-LEVEL MODULES
#     129 ###########################################################
#     130
#     131 # Import top-level functionality into top-level namespace
# --> 133 from nltk.collocations import *
#     134 from nltk.decorators import decorator, memoize
#     135 from nltk.featstruct import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\collocations.py:36
#      33 import itertools as _itertools
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#      39     QuadgramAssocMeasures,
#      40     TrigramAssocMeasures,
#      41 )
#      42 from nltk.metrics.spearman import ranks_from_scores, spearman_correlation
#      43 from nltk.probability import FreqDist
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\metrics\__init__.py:18
#      16 from nltk.metrics.agreement import AnnotationTask
#      17 from nltk.metrics.aline import align
# ---> 18 from nltk.metrics.association import (
#      19     BigramAssocMeasures,
#      20     ContingencyMeasures,
#      21     NgramAssocMeasures,
#      22     QuadgramAssocMeasures,
#      23     TrigramAssocMeasures,
#      24 )
#      25 from nltk.metrics.confusionmatrix import ConfusionMatrix
#      26 from nltk.metrics.distance import (
#      27     binary_distance,
#      28     custom_distance,
#    (...)
#      35     presence,
#      36 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\metrics\association.py:26
#      23 _SMALL = 1e-20
#      25 try:
# ---> 26     from scipy.stats import fisher_exact
#      27 except ImportError:
#      29     def fisher_exact(*_args, **_kwargs):
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\stats\__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:37
#      34 import numpy as np
#      35 from numpy import array, asarray, ma
# ---> 37 from scipy import sparse
#      38 from scipy.spatial.distance import cdist
#      39 from scipy.spatial import distance_matrix
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File c:\Users\Aditya\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\__init__.py:308
#     305 from ._matrix_io import *
#     307 # For backward compatibility with v0.19.
# --> 308 from . import csgraph
#     310 # Deprecated namespaces, to be removed in v2.0.0
#     311 from . import (
#     312     base, bsr, compressed, construct, coo, csc, csr, data, dia, dok, extract,
#     313     lil, sparsetools, sputils
#     314 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\csgraph\__init__.py:185
#     157 __docformat__ = "restructuredtext en"
#     159 __all__ = ['connected_components',
#     160            'laplacian',
#     161            'shortest_path',
#    (...)
#     182            'csgraph_to_masked',
#     183            'NegativeCycleError']
# --> 185 from ._laplacian import laplacian
#     186 from ._shortest_path import (
#     187     shortest_path, floyd_warshall, dijkstra, bellman_ford, johnson,
#     188     NegativeCycleError
#     189 )
#     190 from ._traversal import (
#     191     breadth_first_order, depth_first_order, breadth_first_tree,
#     192     depth_first_tree, connected_components
#     193 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\csgraph\_laplacian.py:7
#       5 import numpy as np
#       6 from scipy.sparse import issparse
# ----> 7 from scipy.sparse.linalg import LinearOperator
#       8 from scipy.sparse._sputils import convert_pydata_sparse_to_scipy, is_pydata_spmatrix
#      11 ###############################################################################
#      12 # Graph laplacian
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\__init__.py:129
#       1 """
#       2 Sparse linear algebra (:mod:`scipy.sparse.linalg`)
#       3 ==================================================
#    (...)
#     126
#     127 """
# --> 129 from ._isolve import *
#     130 from ._dsolve import *
#     131 from ._interface import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\_isolve\__init__.py:4
#       1 "Iterative Solvers for Sparse Linear Systems"
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#       6 from .lgmres import lgmres
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\_isolve\iterative.py:5
#       3 from scipy.sparse.linalg._interface import LinearOperator
#       4 from .utils import make_system
# ----> 5 from scipy.linalg import get_lapack_funcs
#       6 from scipy._lib.deprecation import _NoValue, _deprecate_positional_args
#       8 __all__ = ['bicg', 'bicgstab', 'cg', 'cgs', 'gmres', 'qmr']
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\__init__.py:203
#       1 """
#       2 ====================================
#       3 Linear algebra (:mod:`scipy.linalg`)
#    (...)
#     200
#     201 """  # noqa: E501
# --> 203 from ._misc import *
#     204 from ._cythonized_array_utils import *
#     205 from ._basic import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\_misc.py:3
#       1 import numpy as np
#       2 from numpy.linalg import LinAlgError
# ----> 3 from .blas import get_blas_funcs
#       4 from .lapack import get_lapack_funcs
#       6 __all__ = ['LinAlgError', 'LinAlgWarning', 'norm']
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\blas.py:213
#     210 import numpy as _np
#     211 import functools
# --> 213 from scipy.linalg import _fblas
#     214 try:
#     215     from scipy.linalg import _cblas
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_line_magic('run', 'EDA-Random-model-Univariate-2.ipynb')
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:737, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     735     with preserve_keys(self.shell.user_ns, '__file__'):
#     736         self.shell.user_ns['__file__'] = filename
# --> 737         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     738     return
#     740 # Control the response to exit() calls made by the script being run
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3005, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    3003 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    3004 if raise_exceptions:
# -> 3005     result.raise_error()
#    3006 elif not result.success:
#    3007     break
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:308, in ExecutionResult.raise_error(self)
#     306     raise self.error_before_exec
#     307 if self.error_in_exec is not None:
# --> 308     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_6660\2285066288.py:3
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 from nltk.corpus import stopwords
#       4 import re
#       5 import time
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\__init__.py:133
#     125     subprocess.Popen = _fake_Popen
#     127 ###########################################################
#     128 # TOP-LEVEL MODULES
#     129 ###########################################################
#     130
#     131 # Import top-level functionality into top-level namespace
# --> 133 from nltk.collocations import *
#     134 from nltk.decorators import decorator, memoize
#     135 from nltk.featstruct import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\collocations.py:36
#      33 import itertools as _itertools
#      35 # these two unused imports are referenced in collocations.doctest
# ---> 36 from nltk.metrics import (
#      37     BigramAssocMeasures,
#      38     ContingencyMeasures,
#      39     QuadgramAssocMeasures,
#      40     TrigramAssocMeasures,
#      41 )
#      42 from nltk.metrics.spearman import ranks_from_scores, spearman_correlation
#      43 from nltk.probability import FreqDist
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\metrics\__init__.py:18
#      16 from nltk.metrics.agreement import AnnotationTask
#      17 from nltk.metrics.aline import align
# ---> 18 from nltk.metrics.association import (
#      19     BigramAssocMeasures,
#      20     ContingencyMeasures,
#      21     NgramAssocMeasures,
#      22     QuadgramAssocMeasures,
#      23     TrigramAssocMeasures,
#      24 )
#      25 from nltk.metrics.confusionmatrix import ConfusionMatrix
#      26 from nltk.metrics.distance import (
#      27     binary_distance,
#      28     custom_distance,
#    (...)
#      35     presence,
#      36 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\nltk\metrics\association.py:26
#      23 _SMALL = 1e-20
#      25 try:
# ---> 26     from scipy.stats import fisher_exact
#      27 except ImportError:
#      29     def fisher_exact(*_args, **_kwargs):
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\stats\__init__.py:606
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     601
#     602 """  # noqa: E501
#     604 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     605                                DegenerateDataWarning, FitError)
# --> 606 from ._stats_py import *
#     607 from ._variation import variation
#     608 from .distributions import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:37
#      34 import numpy as np
#      35 from numpy import array, asarray, ma
# ---> 37 from scipy import sparse
#      38 from scipy.spatial.distance import cdist
#      39 from scipy.spatial import distance_matrix
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\__init__.py:134, in __getattr__(name)
#     132 def __getattr__(name):
#     133     if name in submodules:
# --> 134         return _importlib.import_module(f'scipy.{name}')
#     135     else:
#     136         try:
#
# File c:\Users\Aditya\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\__init__.py:308
#     305 from ._matrix_io import *
#     307 # For backward compatibility with v0.19.
# --> 308 from . import csgraph
#     310 # Deprecated namespaces, to be removed in v2.0.0
#     311 from . import (
#     312     base, bsr, compressed, construct, coo, csc, csr, data, dia, dok, extract,
#     313     lil, sparsetools, sputils
#     314 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\csgraph\__init__.py:185
#     157 __docformat__ = "restructuredtext en"
#     159 __all__ = ['connected_components',
#     160            'laplacian',
#     161            'shortest_path',
#    (...)
#     182            'csgraph_to_masked',
#     183            'NegativeCycleError']
# --> 185 from ._laplacian import laplacian
#     186 from ._shortest_path import (
#     187     shortest_path, floyd_warshall, dijkstra, bellman_ford, johnson,
#     188     NegativeCycleError
#     189 )
#     190 from ._traversal import (
#     191     breadth_first_order, depth_first_order, breadth_first_tree,
#     192     depth_first_tree, connected_components
#     193 )
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\csgraph\_laplacian.py:7
#       5 import numpy as np
#       6 from scipy.sparse import issparse
# ----> 7 from scipy.sparse.linalg import LinearOperator
#       8 from scipy.sparse._sputils import convert_pydata_sparse_to_scipy, is_pydata_spmatrix
#      11 ###############################################################################
#      12 # Graph laplacian
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\__init__.py:129
#       1 """
#       2 Sparse linear algebra (:mod:`scipy.sparse.linalg`)
#       3 ==================================================
#    (...)
#     126
#     127 """
# --> 129 from ._isolve import *
#     130 from ._dsolve import *
#     131 from ._interface import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\_isolve\__init__.py:4
#       1 "Iterative Solvers for Sparse Linear Systems"
#       3 #from info import __doc__
# ----> 4 from .iterative import *
#       5 from .minres import minres
#       6 from .lgmres import lgmres
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\sparse\linalg\_isolve\iterative.py:5
#       3 from scipy.sparse.linalg._interface import LinearOperator
#       4 from .utils import make_system
# ----> 5 from scipy.linalg import get_lapack_funcs
#       6 from scipy._lib.deprecation import _NoValue, _deprecate_positional_args
#       8 __all__ = ['bicg', 'bicgstab', 'cg', 'cgs', 'gmres', 'qmr']
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\__init__.py:203
#       1 """
#       2 ====================================
#       3 Linear algebra (:mod:`scipy.linalg`)
#    (...)
#     200
#     201 """  # noqa: E501
# --> 203 from ._misc import *
#     204 from ._cythonized_array_utils import *
#     205 from ._basic import *
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\_misc.py:3
#       1 import numpy as np
#       2 from numpy.linalg import LinAlgError
# ----> 3 from .blas import get_blas_funcs
#       4 from .lapack import get_lapack_funcs
#       6 __all__ = ['LinAlgError', 'LinAlgWarning', 'norm']
#
# File c:\Users\Aditya\anaconda3\Lib\site-packages\scipy\linalg\blas.py:213
#     210 import numpy as _np
#     211 import functools
# --> 213 from scipy.linalg import _fblas
#     214 try:
#     215     from scipy.linalg import _cblas
#
# KeyboardInterrupt:

# %%
from scipy.sparse import hstack
from tabulate import tabulate

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))


train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_))
    
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_))
# Out:
# for C = 1e-05
# Log Loss : 1.3660570324283663
# for C = 0.0001
# Log Loss : 1.2354028010480733
# for C = 0.001
# Log Loss : 1.1847494689551685
# for C = 0.01
# Log Loss : 1.1787957636971413
# for C = 0.1
# Log Loss : 1.3220570972621448
# for C = 1
# Log Loss : 1.7179298903675477
# for C = 10
# Log Loss : 1.739347182860134
# for C = 100
# Log Loss : 1.7393471721180163
# For values of best alpha =  0.01 The train log loss is: 0.7186517583216057
# For values of best alpha =  0.01 The cross validation log loss is: 1.1787957636971413
# For values of best alpha =  0.01 The test log loss is: 1.1754437434245957

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1787957636971413
# Number of mis-classified points : 0.37030075187969924
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_imp_feature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.037  0.043  0.0059 0.071  0.0103 0.7614 0.0644 0.0031 0.0039]]
# Actual Class : 6
# --------------------------------------------------
# 11 most important features are present in our query point
# --------------------------------------------------
#   Index  Feature name            Present or Not
# -------  ----------------------  ----------------
#       0  Gene                    BRCA1
#       1  Gene                    BRCA1
#       2  Gene                    BRCA1
#       3  Gene                    BRCA1
#       4  1167                    False
#       5  Gene                    BRCA1
#       6  Gene                    BRCA1
#       7  Gene                    BRCA1
#       8  Gene                    BRCA1
#       9  1169                    False
#      10  Gene                    BRCA1
#      11  Gene                    BRCA1
#      12  Gene                    BRCA1
#      13  Gene                    BRCA1
#      14  Gene                    BRCA1
#      15  1052g                   False
#      16  stata                   False
#      17  orazi                   False
#      18  3395c                   False
#      19  cahill                  False
#      20  anonymously             False
#      21  xenobiotics             False
#      22  estonia                 False
#      23  icn1                    False
#      24  smarca4                 False
#      25  diterran                False
#      26  Gene                    BRCA1
#      27  Gene                    BRCA1
#      28  Gene                    BRCA1
#      29  Gene                    BRCA1
#      30  692                     False
#      31  morial                  False
#      32  detec                   False
#      33  bard1                   True
#      34  letrozole               False
#      35  bertolli                False
#      36  megabase                False
#      37  kyoto                   False
#      38  aoba                    False
#      39  routes                  False
#      40  doxycyclin              False
#      41  rpci                    False
#      42  pathway80               False
#      43  roud                    False
#      44  hirai                   False
#      45  isolate                 False
#      46  c22                     False
#      47  pip2                    False
#      48  gnrh                    False
#      49  approx50                False
#      50  gentle                  False
#      51  g721d                   False
#      52  mapk3                   False
#      53  antiphosphorylated      False
#      54  5q31                    False
#      55  parada                  False
#      56  mapkk1                  False
#      57  ank4                    False
#      58  95th                    False
#      59  ampr                    False
#      60  octamers                False
#      61  rotational              False
#      62  addicted                False
#      63  organism                False
#      64  orford                  False
#      65  95c                     False
#      66  klijn                   False
#      67  ghai                    False
#      68  Gene                    BRCA1
#      69  Gene                    BRCA1
#      70  Gene                    BRCA1
#      71  Gene                    BRCA1
#      72  cpk                     False
#      73  asp770                  False
#      74  Gene                    BRCA1
#      75  disuse                  False
#      76  cpla2                   False
#      77  nizing                  False
#      78  buti                    False
#      79  Gene                    BRCA1
#      80  Gene                    BRCA1
#      81  rouach                  False
#      82  f460                    False
#      83  Index out of bounds     False
#      84  Gene                    BRCA1
#      85  Gene                    BRCA1
#      86  Gene                    BRCA1
#      87  Gene                    BRCA1
#      88  cpierre                 False
#      89  antitumoral             False
#      90  consequence             False
#      91  9755                    False
#      92  blotted                 False
#      93  1525                    False
#      94  Gene                    BRCA1
#      95  ep1058y                 False
#      96  9000                    False
#      97  Index out of bounds     False
#      98  forskolin               False
#      99  Gene                    BRCA1
#     100  Gene                    BRCA1
#     101  Gene                    BRCA1
#     102  Gene                    BRCA1
#     103  ln319                   False
#     104  millot                  False
#     105  tsc2gapa                False
#     106  g75r                    False
#     107  methylphenyl            False
#     108  pdgfa                   False
#     109  Gene                    BRCA1
#     110  Gene                    BRCA1
#     111  Gene                    BRCA1
#     112  joo                     False
#     113  sialic                  False
#     114  transillumination       False
#     115  mycoplasma              False
#     116  bernoulli               False
#     117  tequation               False
#     118  3kd                     False
#     119  fp                      False
#     120  georgia                 False
#     121  roselab                 False
#     122  lm200                   False
#     123  zc25                    False
#     124  unprecedented           False
#     125  Gene                    BRCA1
#     126  Gene                    BRCA1
#     127  Gene                    BRCA1
#     128  lestaurtinib            False
#     129  resampling              False
#     130  doxycycline             False
#     131  telangectasia           False
#     132  imposed                 False
#     133  cnas                    False
#     134  berlin                  False
#     135  spreadsheets            False
#     136  Gene                    BRCA1
#     137  Gene                    BRCA1
#     138  1cs4                    False
#     139  Gene                    BRCA1
#     140  bypassing               False
#     141  wilsonville             False
#     142  leveraged               False
#     143  clg                     False
#     144  exchanges               False
#     145  consolidate             False
#     146  hepatology              False
#     147  tta                     False
#     148  calonge                 False
#     149  haematopoiesis4         False
#     150  prkcb                   False
#     151  oligodimerization       False
#     152  ap3b1                   False
#     153  deshaies                False
#     154  histomorphology         False
#     155  suitable                False
#     156  lethals                 False
#     157  fungus                  False
#     158  lewis                   False
#     159  cr2                     False
#     160  t185                    False
#     161  gsk1363089              False
#     162  r283c                   False
#     163  rp1                     False
#     164  dpp3                    False
#     165  journals                True
#     166  facilitated             False
#     167  document                False
#     168  yacs                    False
#     169  dhand                   False
#     170  544                     False
#     171  402                     False
#     172  documentation           False
#     173  intraperitoneal         False
#     174  Index out of bounds     False
#     175  serizawa                False
#     176  gid380                  False
#     177  thoracoscopic           False
#     178  subjective              False
#     179  Gene                    BRCA1
#     180  1113                    False
#     181  Gene                    BRCA1
#     182  Gene                    BRCA1
#     183  Gene                    BRCA1
#     184  Gene                    BRCA1
#     185  gin61                   False
#     186  sensitive               True
#     187  p753                    False
#     188  contingency             False
#     189  advantageous            False
#     190  myc                     False
#     191  perfect                 False
#     192  mxsf3b1mut              False
#     193  4233                    False
#     194  polysomic               False
#     195  membrane                False
#     196  5057a                   False
#     197  arrowc                  False
#     198  seven                   True
#     199  kidneys                 False
#     200  Index out of bounds     False
#     201  gin                     False
#     202  krasg60r                False
#     203  chemical                True
#     204  clock                   False
#     205  phytohemagglutinin      False
#     206  pointing                False
#     207  golga4                  False
#     208  journey                 False
#     209  5insa                   False
#     210  e221q                   False
#     211  lysate                  False
#     212  5i                      False
#     213  ig32                    False
#     214  dusp6                   False
#     215  mason                   False
#     216  a1708v                  False
#     217  f583                    False
#     218  tumourigenesis          True
#     219  dsrct                   False
#     220  matter                  False
#     221  drug101                 False
#     222  matos                   False
#     223  matologie               False
#     224  mapkk2                  False
#     225  ab5408                  False
#     226  567                     False
#     227  chemicon                False
#     228  runx3                   False
#     229  longitudinally          False
#     230  sms                     False
#     231  golemis                 False
#     232  hook                    False
#     233  yl                      False
#     234  jx013981                False
#     235  clumps                  False
#     236  jupiter                 False
#     237  restreaked              False
#     238  jsf                     False
#     239  cmin                    False
#     240  journal                 False
#     241  jo                      True
#     242  jnks                    False
#     243  haplotype               False
#     244  pointed                 False
#     245  cancer3                 False
#     246  topcount                False
#     247  jp                      False
#     248  sparse                  False
#     249  closes                  False
#     250  clones                  True
#     251  lod                     False
#     252  alfageme                False
#     253  locally                 False
#     254  lobule                  False
#     255  chaps                   False
#     256  lobe                    False
#     257  alv                     False
#     258  stransferase            False
#     259  clonetech               False
#     260  reutlingen              False
#     261  geared                  False
#     262  monodelphis             False
#     263  chemidoc                False
#     264  spindling               False
#     265  gebbink                 False
#     266  spectroscopic           False
#     267  pathogens               False
#     268  annexinv                False
#     269  chemifluorescence       False
#     270  smokers                 False
#     271  rounding                False
#     272  tumbling                False
#     273  Index out of bounds     False
#     274  equalized               False
#     275  Gene                    BRCA1
#     276  Gene                    BRCA1
#     277  Gene                    BRCA1
#     278  ttrap                   False
#     279  wisconsin               False
#     280  leu137                  False
#     281  2053                    False
#     282  identi                  True
#     283  batches                 False
#     284  heterooligomer          False
#     285  7178139                 False
#     286  7264                    False
#     287  havana                  False
#     288  macrocytic              False
#     289  phosphoinositide        False
#     290  gggggtctttca            False
#     291  g384d                   False
#     292  promising               False
#     293  tumorigenicity          False
#     294  doxycyclineinducible    False
#     295  methylation112          False
#     296  phosphokinase           False
#     297  closing                 False
#     298  wet                     False
#     299  agggacacacgatgggcttctg  False
#     300  erica                   False
#     301  virus                   False
#     302  r105s                   False
#     303  seriously               False
#     304  bundy                   False
#     305  l858q                   False
#     306  intentionally           False
#     307  Gene                    BRCA1
#     308  Gene                    BRCA1
#     309  Gene                    BRCA1
#     310  herndon                 False
#     311  spheres                 True
#     312  gradation               False
#     313  e543                    False
#     314  55b11                   False
#     315  diagrammatic            False
#     316  ep                      False
#     317  predefined              False
#     318  stable                  False
#     319  teleconference          False
#     320  396c                    False
#     321  correlating             False
#     322  acquisition             False
#     323  pressing                False
#     324  wisdom                  False
#     325  grouped                 False
#     326  cellu                   False
#     327  cebpa                   False
#     328  spacer                  False
#     329  antigenicity            False
#     330  f603                    False
#     331  l32p                    False
#     332  salpingo                False
#     333  digit                   False
#     334  kratz                   False
#     335  val45                   False
#     336  attain                  False
#     337  Index out of bounds     False
#     338  047                     False
#     339  neurosurgery            False
#     340  1he8                    False
#     341  0216                    False
#     342  13601a02                False
#     343  13department            False
#     344  customize               False
#     345  1699                    False
#     346  1147                    False
#     347  079                     False
#     348  1985                    False
#     349  1999a                   False
#     350  191170                  False
#     351  1739                    False
#     352  1854stop                False
#     353  1780gvpql               False
#     354  12h                     False
#     355  15513a02                False
#     356  10bp                    False
#     357  1928                    False
#     358  1812                    False
#     359  1258                    False
#     360  1x105                   False
#     361  1840                    False
#     362  1330                    False
#     363  0973                    False
#     364  Gene                    BRCA1
#     365  201                     False
#     366  1283                    False
#     367  16s                     False
#     368  120k                    False
#     369  1410                    False
#     370  1800g                   False
#     371  100x                    False
#     372  1689                    False
#     373  1536                    False
#     374  1delinsaa               False
#     375  1508g                   False
#     376  181l                    False
#     377  1751g                   False
#     378  Gene                    BRCA1
#     379  1946                    False
#     380  10n                     False
#     381  1490                    False
#     382  1288                    False
#     383  10t                     False
#     384  11l576p                 False
#     385  1126                    False
#     386  1078t                   False
#     387  039                     False
#     388  1221                    False
#     389  11v559d                 False
#     390  11q                     False
#     391  1747                    False
#     392  2002c                   False
#     393  Gene                    BRCA1
#     394  1158                    False
#     395  1447                    False
#     396  0m                      False
#     397  182a                    False
#     398  1097                    False
#     399  1a1a                    False
#     400  19ex                    False
#     401  1853aa                  False
#     402  10q23                   False
#     403  18mm                    False
#     404  1811                    False
#     405  1r2d                    False
#     406  097                     False
#     407  153                     False
#     408  10710                   False
#     409  Gene                    BRCA1
#     410  1074                    False
#     411  15t                     False
#     412  1855stop                False
#     413  1969                    False
#     414  1d3                     False
#     415  0other                  False
#     416  11number                False
#     417  176876                  False
#     418  132                     False
#     419  1uwj                    False
#     420  181                     False
#     421  1000x                   False
#     422  Gene                    BRCA1
#     423  1212                    False
#     424  1225                    False
#     425  1h                      False
#     426  1616                    False
#     427  1259                    False
#     428  1459                    False
#     429  Gene                    BRCA1
#     430  1tsr                    False
#     431  1135                    False
#     432  131a                    False
#     433  Gene                    BRCA1
#     434  1274                    False
#     435  1820                    False
#     436  1871                    False
#     437  0368                    False
#     438  19f13                   False
#     439  19                      True
#     440  Gene                    BRCA1
#     441  19075706                False
#     442  1469                    False
#     443  100ug                   False
#     444  1604del                 False
#     445  1962                    False
#     446  15q26                   False
#     447  1968                    False
#     448  10a                     False
#     449  0222                    False
#     450  cd74                    False
#     451  cd44                    False
#     452  03                      False
#     453  1interspecific          False
#     454  103splice               False
#     455  12b                     False
#     456  1302                    False
#     457  021                     False
#     458  1241                    False
#     459  1073t                   False
#     460  02                      False
#     461  y1092                   False
#     462  200kb                   False
#     463  11kvvee558              False
#     464  105k                    False
#     465  15q22                   False
#     466  1995                    False
#     467  1519                    False
#     468  17p                     False
#     469  1349                    False
#     470  0211                    False
#     471  13b                     False
#     472  4836                    False
#     473  multinuclear            False
#     474  Index out of bounds     False
#     475  r174                    False
#     476  exonskipping            False
#     477  mpi                     False
#     478  cytospins               False
#     479  coil                    False
#     480  hipaa                   False
#     481  ca2                     False
#     482  medulla                 False
#     483  mapk8                   False
#     484  kbf2                    False
#     485  f605                    False
#     486  y345h                   False
#     487  reviewers               False
#     488  f6                      False
#     489  arg333                  False
#     490  targetplus              False
#     491  kirschner               False
#     492  helixout                False
#     493  quantitatively          False
#     494  gau                     False
#     495  6800                    False
#     496  indistinguishably       False
#     497  wishart                 False
#     498  archetypal              False
#     499  i565                    False

# %%
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_imp_feature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 6
# Predicted Class Probabilities: [[0.037  0.043  0.0059 0.071  0.0103 0.7614 0.0644 0.0031 0.0039]]
# Actual Class : 6
# --------------------------------------------------
# 11 most important features are present in our query point
# --------------------------------------------------
#   Index  Feature name            Present or Not
# -------  ----------------------  ----------------
#       0  Gene                    BRCA1
#       1  Gene                    BRCA1
#       2  Gene                    BRCA1
#       3  Gene                    BRCA1
#       4  1167                    False
#       5  Gene                    BRCA1
#       6  Gene                    BRCA1
#       7  Gene                    BRCA1
#       8  Gene                    BRCA1
#       9  1169                    False
#      10  Gene                    BRCA1
#      11  Gene                    BRCA1
#      12  Gene                    BRCA1
#      13  Gene                    BRCA1
#      14  Gene                    BRCA1
#      15  1052g                   False
#      16  stata                   False
#      17  orazi                   False
#      18  3395c                   False
#      19  cahill                  False
#      20  anonymously             False
#      21  xenobiotics             False
#      22  estonia                 False
#      23  icn1                    False
#      24  smarca4                 False
#      25  diterran                False
#      26  Gene                    BRCA1
#      27  Gene                    BRCA1
#      28  Gene                    BRCA1
#      29  Gene                    BRCA1
#      30  692                     False
#      31  morial                  False
#      32  detec                   False
#      33  bard1                   True
#      34  letrozole               False
#      35  bertolli                False
#      36  megabase                False
#      37  kyoto                   False
#      38  aoba                    False
#      39  routes                  False
#      40  doxycyclin              False
#      41  rpci                    False
#      42  pathway80               False
#      43  roud                    False
#      44  hirai                   False
#      45  isolate                 False
#      46  c22                     False
#      47  pip2                    False
#      48  gnrh                    False
#      49  approx50                False
#      50  gentle                  False
#      51  g721d                   False
#      52  mapk3                   False
#      53  antiphosphorylated      False
#      54  5q31                    False
#      55  parada                  False
#      56  mapkk1                  False
#      57  ank4                    False
#      58  95th                    False
#      59  ampr                    False
#      60  octamers                False
#      61  rotational              False
#      62  addicted                False
#      63  organism                False
#      64  orford                  False
#      65  95c                     False
#      66  klijn                   False
#      67  ghai                    False
#      68  Gene                    BRCA1
#      69  Gene                    BRCA1
#      70  Gene                    BRCA1
#      71  Gene                    BRCA1
#      72  cpk                     False
#      73  asp770                  False
#      74  Gene                    BRCA1
#      75  disuse                  False
#      76  cpla2                   False
#      77  nizing                  False
#      78  buti                    False
#      79  Gene                    BRCA1
#      80  Gene                    BRCA1
#      81  rouach                  False
#      82  f460                    False
#      83  Index out of bounds     False
#      84  Gene                    BRCA1
#      85  Gene                    BRCA1
#      86  Gene                    BRCA1
#      87  Gene                    BRCA1
#      88  cpierre                 False
#      89  antitumoral             False
#      90  consequence             False
#      91  9755                    False
#      92  blotted                 False
#      93  1525                    False
#      94  Gene                    BRCA1
#      95  ep1058y                 False
#      96  9000                    False
#      97  Index out of bounds     False
#      98  forskolin               False
#      99  Gene                    BRCA1
#     100  Gene                    BRCA1
#     101  Gene                    BRCA1
#     102  Gene                    BRCA1
#     103  ln319                   False
#     104  millot                  False
#     105  tsc2gapa                False
#     106  g75r                    False
#     107  methylphenyl            False
#     108  pdgfa                   False
#     109  Gene                    BRCA1
#     110  Gene                    BRCA1
#     111  Gene                    BRCA1
#     112  joo                     False
#     113  sialic                  False
#     114  transillumination       False
#     115  mycoplasma              False
#     116  bernoulli               False
#     117  tequation               False
#     118  3kd                     False
#     119  fp                      False
#     120  georgia                 False
#     121  roselab                 False
#     122  lm200                   False
#     123  zc25                    False
#     124  unprecedented           False
#     125  Gene                    BRCA1
#     126  Gene                    BRCA1
#     127  Gene                    BRCA1
#     128  lestaurtinib            False
#     129  resampling              False
#     130  doxycycline             False
#     131  telangectasia           False
#     132  imposed                 False
#     133  cnas                    False
#     134  berlin                  False
#     135  spreadsheets            False
#     136  Gene                    BRCA1
#     137  Gene                    BRCA1
#     138  1cs4                    False
#     139  Gene                    BRCA1
#     140  bypassing               False
#     141  wilsonville             False
#     142  leveraged               False
#     143  clg                     False
#     144  exchanges               False
#     145  consolidate             False
#     146  hepatology              False
#     147  tta                     False
#     148  calonge                 False
#     149  haematopoiesis4         False
#     150  prkcb                   False
#     151  oligodimerization       False
#     152  ap3b1                   False
#     153  deshaies                False
#     154  histomorphology         False
#     155  suitable                False
#     156  lethals                 False
#     157  fungus                  False
#     158  lewis                   False
#     159  cr2                     False
#     160  t185                    False
#     161  gsk1363089              False
#     162  r283c                   False
#     163  rp1                     False
#     164  dpp3                    False
#     165  journals                True
#     166  facilitated             False
#     167  document                False
#     168  yacs                    False
#     169  dhand                   False
#     170  544                     False
#     171  402                     False
#     172  documentation           False
#     173  intraperitoneal         False
#     174  Index out of bounds     False
#     175  serizawa                False
#     176  gid380                  False
#     177  thoracoscopic           False
#     178  subjective              False
#     179  Gene                    BRCA1
#     180  1113                    False
#     181  Gene                    BRCA1
#     182  Gene                    BRCA1
#     183  Gene                    BRCA1
#     184  Gene                    BRCA1
#     185  gin61                   False
#     186  sensitive               True
#     187  p753                    False
#     188  contingency             False
#     189  advantageous            False
#     190  myc                     False
#     191  perfect                 False
#     192  mxsf3b1mut              False
#     193  4233                    False
#     194  polysomic               False
#     195  membrane                False
#     196  5057a                   False
#     197  arrowc                  False
#     198  seven                   True
#     199  kidneys                 False
#     200  Index out of bounds     False
#     201  gin                     False
#     202  krasg60r                False
#     203  chemical                True
#     204  clock                   False
#     205  phytohemagglutinin      False
#     206  pointing                False
#     207  golga4                  False
#     208  journey                 False
#     209  5insa                   False
#     210  e221q                   False
#     211  lysate                  False
#     212  5i                      False
#     213  ig32                    False
#     214  dusp6                   False
#     215  mason                   False
#     216  a1708v                  False
#     217  f583                    False
#     218  tumourigenesis          True
#     219  dsrct                   False
#     220  matter                  False
#     221  drug101                 False
#     222  matos                   False
#     223  matologie               False
#     224  mapkk2                  False
#     225  ab5408                  False
#     226  567                     False
#     227  chemicon                False
#     228  runx3                   False
#     229  longitudinally          False
#     230  sms                     False
#     231  golemis                 False
#     232  hook                    False
#     233  yl                      False
#     234  jx013981                False
#     235  clumps                  False
#     236  jupiter                 False
#     237  restreaked              False
#     238  jsf                     False
#     239  cmin                    False
#     240  journal                 False
#     241  jo                      True
#     242  jnks                    False
#     243  haplotype               False
#     244  pointed                 False
#     245  cancer3                 False
#     246  topcount                False
#     247  jp                      False
#     248  sparse                  False
#     249  closes                  False
#     250  clones                  True
#     251  lod                     False
#     252  alfageme                False
#     253  locally                 False
#     254  lobule                  False
#     255  chaps                   False
#     256  lobe                    False
#     257  alv                     False
#     258  stransferase            False
#     259  clonetech               False
#     260  reutlingen              False
#     261  geared                  False
#     262  monodelphis             False
#     263  chemidoc                False
#     264  spindling               False
#     265  gebbink                 False
#     266  spectroscopic           False
#     267  pathogens               False
#     268  annexinv                False
#     269  chemifluorescence       False
#     270  smokers                 False
#     271  rounding                False
#     272  tumbling                False
#     273  Index out of bounds     False
#     274  equalized               False
#     275  Gene                    BRCA1
#     276  Gene                    BRCA1
#     277  Gene                    BRCA1
#     278  ttrap                   False
#     279  wisconsin               False
#     280  leu137                  False
#     281  2053                    False
#     282  identi                  True
#     283  batches                 False
#     284  heterooligomer          False
#     285  7178139                 False
#     286  7264                    False
#     287  havana                  False
#     288  macrocytic              False
#     289  phosphoinositide        False
#     290  gggggtctttca            False
#     291  g384d                   False
#     292  promising               False
#     293  tumorigenicity          False
#     294  doxycyclineinducible    False
#     295  methylation112          False
#     296  phosphokinase           False
#     297  closing                 False
#     298  wet                     False
#     299  agggacacacgatgggcttctg  False
#     300  erica                   False
#     301  virus                   False
#     302  r105s                   False
#     303  seriously               False
#     304  bundy                   False
#     305  l858q                   False
#     306  intentionally           False
#     307  Gene                    BRCA1
#     308  Gene                    BRCA1
#     309  Gene                    BRCA1
#     310  herndon                 False
#     311  spheres                 True
#     312  gradation               False
#     313  e543                    False
#     314  55b11                   False
#     315  diagrammatic            False
#     316  ep                      False
#     317  predefined              False
#     318  stable                  False
#     319  teleconference          False
#     320  396c                    False
#     321  correlating             False
#     322  acquisition             False
#     323  pressing                False
#     324  wisdom                  False
#     325  grouped                 False
#     326  cellu                   False
#     327  cebpa                   False
#     328  spacer                  False
#     329  antigenicity            False
#     330  f603                    False
#     331  l32p                    False
#     332  salpingo                False
#     333  digit                   False
#     334  kratz                   False
#     335  val45                   False
#     336  attain                  False
#     337  Index out of bounds     False
#     338  047                     False
#     339  neurosurgery            False
#     340  1he8                    False
#     341  0216                    False
#     342  13601a02                False
#     343  13department            False
#     344  customize               False
#     345  1699                    False
#     346  1147                    False
#     347  079                     False
#     348  1985                    False
#     349  1999a                   False
#     350  191170                  False
#     351  1739                    False
#     352  1854stop                False
#     353  1780gvpql               False
#     354  12h                     False
#     355  15513a02                False
#     356  10bp                    False
#     357  1928                    False
#     358  1812                    False
#     359  1258                    False
#     360  1x105                   False
#     361  1840                    False
#     362  1330                    False
#     363  0973                    False
#     364  Gene                    BRCA1
#     365  201                     False
#     366  1283                    False
#     367  16s                     False
#     368  120k                    False
#     369  1410                    False
#     370  1800g                   False
#     371  100x                    False
#     372  1689                    False
#     373  1536                    False
#     374  1delinsaa               False
#     375  1508g                   False
#     376  181l                    False
#     377  1751g                   False
#     378  Gene                    BRCA1
#     379  1946                    False
#     380  10n                     False
#     381  1490                    False
#     382  1288                    False
#     383  10t                     False
#     384  11l576p                 False
#     385  1126                    False
#     386  1078t                   False
#     387  039                     False
#     388  1221                    False
#     389  11v559d                 False
#     390  11q                     False
#     391  1747                    False
#     392  2002c                   False
#     393  Gene                    BRCA1
#     394  1158                    False
#     395  1447                    False
#     396  0m                      False
#     397  182a                    False
#     398  1097                    False
#     399  1a1a                    False
#     400  19ex                    False
#     401  1853aa                  False
#     402  10q23                   False
#     403  18mm                    False
#     404  1811                    False
#     405  1r2d                    False
#     406  097                     False
#     407  153                     False
#     408  10710                   False
#     409  Gene                    BRCA1
#     410  1074                    False
#     411  15t                     False
#     412  1855stop                False
#     413  1969                    False
#     414  1d3                     False
#     415  0other                  False
#     416  11number                False
#     417  176876                  False
#     418  132                     False
#     419  1uwj                    False
#     420  181                     False
#     421  1000x                   False
#     422  Gene                    BRCA1
#     423  1212                    False
#     424  1225                    False
#     425  1h                      False
#     426  1616                    False
#     427  1259                    False
#     428  1459                    False
#     429  Gene                    BRCA1
#     430  1tsr                    False
#     431  1135                    False
#     432  131a                    False
#     433  Gene                    BRCA1
#     434  1274                    False
#     435  1820                    False
#     436  1871                    False
#     437  0368                    False
#     438  19f13                   False
#     439  19                      True
#     440  Gene                    BRCA1
#     441  19075706                False
#     442  1469                    False
#     443  100ug                   False
#     444  1604del                 False
#     445  1962                    False
#     446  15q26                   False
#     447  1968                    False
#     448  10a                     False
#     449  0222                    False
#     450  cd74                    False
#     451  cd44                    False
#     452  03                      False
#     453  1interspecific          False
#     454  103splice               False
#     455  12b                     False
#     456  1302                    False
#     457  021                     False
#     458  1241                    False
#     459  1073t                   False
#     460  02                      False
#     461  y1092                   False
#     462  200kb                   False
#     463  11kvvee558              False
#     464  105k                    False
#     465  15q22                   False
#     466  1995                    False
#     467  1519                    False
#     468  17p                     False
#     469  1349                    False
#     470  0211                    False
#     471  13b                     False
#     472  4836                    False
#     473  multinuclear            False
#     474  Index out of bounds     False
#     475  r174                    False
#     476  exonskipping            False
#     477  mpi                     False
#     478  cytospins               False
#     479  coil                    False
#     480  hipaa                   False
#     481  ca2                     False
#     482  medulla                 False
#     483  mapk8                   False
#     484  kbf2                    False
#     485  f605                    False
#     486  y345h                   False
#     487  reviewers               False
#     488  f6                      False
#     489  arg333                  False
#     490  targetplus              False
#     491  kirschner               False
#     492  helixout                False
#     493  quantitatively          False
#     494  gau                     False
#     495  6800                    False
#     496  indistinguishably       False
#     497  wishart                 False
#     498  archetypal              False
#     499  i565                    False

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def get_imp_feature_names(indices, text, gene, variation, no_feature, removed_ind = [], predicted_cls=None):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", gene])
        elif i < 18:
            tabulte_list.append([incresingorder_ind, "Variation", variation])
        elif (i > 17) and (i not in removed_ind):
            # Check bounds before accessing train_text_features
            if i < len(train_text_features):
                word = train_text_features[i]
                yes_no = True if word in text.split() else False
                if yes_no:
                    word_present += 1
                tabulte_list.append([incresingorder_ind, word, yes_no])
            else:
                tabulte_list.append([incresingorder_ind, "Index out of bounds", False])
        incresingorder_ind += 1
    print(word_present, "most important features are present in our query point")
    print("-"*50)
    if predicted_cls is not None:
        print("The features that are most important for the ", predicted_cls[0], " class:")
    print(tabulate(tabulte_list, headers=["Index", 'Feature name', 'Present or Not']))

# %%
# Using kernel with balaned data and response coding

# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
    clf = SVC(C=i, kernel='rbf', probability=True, class_weight='balanced', random_state=42)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_))
    
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf =  SVC(C=alpha[best_alpha], kernel='rbf', probability=True, class_weight='balanced', random_state=42)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_))
# Out:
# for C = 1e-05
# Log Loss : 1.2175008368645226
# for C = 0.0001
# Log Loss : 1.2186557736654104
# for C = 0.001
# Log Loss : 1.22980220103486
# for C = 0.01
# Log Loss : 1.3156963104467558
# for C = 0.1
# Log Loss : 1.2121604711641139
# for C = 1
# Log Loss : 1.225532574612497
# for C = 10
# Log Loss : 1.8108397124797
# for C = 100
# Log Loss : 1.8444888666019463
# For values of best alpha =  0.1 The train log loss is: 1.0604475420622754
# For values of best alpha =  0.1 The cross validation log loss is: 1.2121604711641139
# For values of best alpha =  0.1 The test log loss is: 1.2370584712680996
